# %%
#1
import pandas as pd

Sig_Eqs= pd.read_csv('earthquakes-2021-10-23_11-03-55_+0800.txt',sep='\t')
Sig_Eqs[Sig_Eqs['Country'] == 'AUSTRALIA'].sort_values('Mag',ascending=False)
#1.2
M=Sig_Eqs[Sig_Eqs['Mag']>6].groupby('Year').count()['Mag']
M.plot(kind='line')
#Sig_Eqs['Mag']
#可以观察到地震数量变化的趋势。观察到随着时间增长地震总数整体上在逐渐增加。在1500年后，大于6级的地震数量明显增加。这其中有几点原因，第一点可能是1500年前发生地震的数量大部分没有被记录下来，或者记录的数据丢失了。其二可能是随着科技的发展监测地震的仪器越来越先进对全球的地震数量都能准确的监测到。最后一点是在1500年
#采用了以年为组别，计数每年地震级别大于6的次数，并以年为横轴绘制了折线图，通过折线图的变化可体现出每年震级大于6的地震次数随时间的变化。
# Out:
# <AxesSubplot:xlabel='Year'>
