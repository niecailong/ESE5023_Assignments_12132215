# %%
#3.1
import pandas as pd
sample=pd.read_csv('sample.csv')
#读取了Global Surface Summary of the Day - GSOD的数据，数据来源于NOAA Land-Based Datasets and Products
#数据的网址：https://www.ncei.noaa.gov/access/search/dataset-search?observationTypes=Land%20Surface
# del sample['STATION''NAME']
sample
# Out:
#            DATE  PRCP
# 0    2018-01-01   0.0
# 1    2018-01-02   0.0
# 2    2018-01-03   0.0
# 3    2018-01-04   0.0
# 4    2018-01-05   0.0
# ..          ...   ...
# 360  2018-12-27   0.0
# 361  2018-12-28   0.0
# 362  2018-12-29   0.0
# 363  2018-12-30   0.0
# 364  2018-12-31   0.0
#
# [365 rows x 2 columns]

# %%
D=sample.loc[:,['DATE','PRCP']]
D
# Out:
#            DATE  PRCP
# 0    2018-01-01   0.0
# 1    2018-01-02   0.0
# 2    2018-01-03   0.0
# 3    2018-01-04   0.0
# 4    2018-01-05   0.0
# ..          ...   ...
# 360  2018-12-27   0.0
# 361  2018-12-28   0.0
# 362  2018-12-29   0.0
# 363  2018-12-30   0.0
# 364  2018-12-31   0.0
#
# [365 rows x 2 columns]
